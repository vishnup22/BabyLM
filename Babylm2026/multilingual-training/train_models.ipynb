# %%
import subprocess


script = """python train.py \
  --dataset BabyLM-community/babylm-nor \
  --config ./model_config.json \
  --output_dir ./nor-baseline-small \
  --model_name BabyLM-community/nor-baseline-small \
  --push_to_hub
"""

subprocess.run(script, shell=True, executable="/bin/bash")
# Out:
# 📥 Loading dataset...
# 🔡 Training BPE tokenizer...
# 🧹 Tokenizing dataset...
# Map: 100%|██████████| 493/493 [00:01<00:00, 308.96 examples/s]
# /gpfs/home4/jumelet/jupyter/multilingual-training/train.py:110: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# 🔧 Loading model config and initializing model...
# 🚀 Starting training...
# ...
# 100%|██████████| 2793/2793 [01:42<00:00, 27.21it/s]
# No files have been modified since last commit. Skipping to prevent empty commit.
# {'loss': 5.3774, 'grad_norm': 1.8848546743392944, 'learning_rate': 4.1066953097028285e-05, 'epoch': 0.54}
# {'loss': 4.6432, 'grad_norm': 2.5089685916900635, 'learning_rate': 3.2116004296455426e-05, 'epoch': 1.07}
# {'loss': 4.4328, 'grad_norm': 1.6926122903823853, 'learning_rate': 2.3165055495882564e-05, 'epoch': 1.61}
# ...
